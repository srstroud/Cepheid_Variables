# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Recreating the 1912 Figures

# %%
leavitt = np.loadtxt('1912_Periods.txt', skiprows=1)
lea_harvard = leavitt[:,0]
lea_max = leavitt[:,1]
lea_min = leavitt[:,2]
lea_per = leavitt[:,3]
lea_pern = np.sort(lea_per)
ind = np.argsort(lea_per)
lea_maxn = lea_max[ind]
lea_minn = lea_min[ind]

# %%
print(np.sort(lea_harvard))
print(len(lea_harvard))
# Out:
# [ 818.  821.  822.  823.  824.  827.  842. 1351. 1355. 1365. 1374. 1400.
#  1413. 1422. 1425. 1436. 1446. 1460. 1492. 1505. 1506. 1610. 1646. 1649.
#  1742.]
# 25

# %%
plt.plot(lea_pern, lea_maxn, 'b.-')
plt.plot(lea_pern, lea_minn, 'b.-')
plt.gca().invert_yaxis()
plt.title('Circular 173, Fig 1')
plt.xlabel('Period')
plt.ylabel('Brightness')
#plt.savefig('Fig1.pdf', bboxes='tight')
plt.show()

# %%
x = np.log10(lea_pern)
y1 = lea_maxn 
y2 = lea_minn
z1 = np.polyfit(x, y1, 1)
p1 = np.poly1d(z1)
z2 = np.polyfit(x, y2, 1)
p2 = np.poly1d(z2)

plt.plot(x, y1, 'bo-')
plt.plot(x, y2, 'bo-')
plt.plot(x, p1(x),"b--")
plt.plot(x, p2(x),"b--")
plt.gca().invert_yaxis()

plt.title('Circular 173, Fig 2')
plt.xlabel('log(Period)')
plt.ylabel('Brightness')

#plt.savefig('Fig2.pdf', bboxes='tight')
plt.show()

# %% [markdown]
# # Tuscana Cepheids in GCVS 5.1

# %%
gcvs = np.loadtxt('gcvs5_periods.txt', skiprows=2, usecols=(0,4,5,10), delimiter='|')
gcvs_number = gcvs[:,0]
gcvs_max = gcvs[:,1]
gcvs_min = gcvs[:,2]
gcvs_per = gcvs[:,3]
gcvs_pern = np.sort(gcvs_per)
ind = np.argsort(gcvs_per)
gcvs_maxn = gcvs_max[ind]
gcvs_minn = gcvs_min[ind]

# %%
plt.plot(lea_pern, lea_maxn, 'b.-')
plt.plot(lea_pern, lea_minn, 'b.-')
plt.plot(gcvs_pern, gcvs_maxn, 'r.-')
plt.plot(gcvs_pern, gcvs_minn, 'r.-')
plt.gca().invert_yaxis()

plt.title('Historical and Modern SMC Cepheids')
plt.xlabel('Period')
plt.ylabel('Brightness')

#plt.savefig('Fig1_New.pdf', bboxes='tight')
plt.show()

# %%
x1, x2 = np.log10(lea_pern), np.log10(gcvs_pern)
y1, y2, y3, y4 = lea_maxn, lea_minn, gcvs_maxn, gcvs_minn

z1 = np.polyfit(x, y1, 1)
p1 = np.poly1d(z1)
z2 = np.polyfit(x, y2, 1) 
p2 = np.poly1d(z2)
z3 = np.polyfit(x2, y3, 1) 
p3 = np.poly1d(z3)
z4 = np.polyfit(x2, y4, 1)
p4 = np.poly1d(z4)

plt.plot(x, y1, 'b.-')
plt.plot(x, y2, 'b.-')
plt.plot(x2, y3, 'r.-')
plt.plot(x2, y4, 'r.-')
plt.plot(x, p1(x),"b--")
plt.plot(x, p2(x),"b--")
plt.plot(x2, p3(x2),"r--")
plt.plot(x2, p4(x2),"r--")
plt.gca().invert_yaxis()

plt.title('Historical and Modern SMC Cepheids')
plt.xlabel('log(Period)')
plt.ylabel('Brightness')

#plt.savefig('Fig2_New.pdf', bboxes='tight')
plt.show()

# %% [markdown]
# # Small Magellanic Cloud Cepheids in CEVS

# %%
evs = np.genfromtxt('EVS_CAT_SMC_noout.txt', usecols=(0,6,7,9))
evs_number = evs[:,0]
evs_max = evs[:,1]
evs_min = evs[:,2]
evs_per = evs[:,3]
evs_pern = np.sort(evs_per)
ind = np.argsort(evs_per)
evs_maxn = evs_max[ind]
evs_minn = evs_min[ind]
print(len(evs_number))
# Out:
# 1179

# %%
plt.plot(evs_pern, evs_maxn, 'g.')
plt.plot(evs_pern, evs_minn, 'm.')
plt.gca().invert_yaxis()

plt.title('SMC Cepheids in the CEVS')
plt.xlabel('Period')
plt.ylabel('Brightness')

#plt.savefig('Fig1_New.pdf', bboxes='tight')
plt.show()

# %%
plt.plot(np.log10(evs_pern), evs_maxn, 'g.')
plt.plot(np.log10(evs_pern), evs_minn, 'm.')
plt.gca().invert_yaxis()

plt.title('SMC Cepheids in the CEVS')
plt.xlabel('log(Period)')
plt.ylabel('Brightness')

#plt.savefig('Fig1_New.pdf', bboxes='tight')
plt.show()

# %%
#%matplotlib notebook
x1 = np.log10(lea_pern)
x2 = np.log10(evs_pern)
y1 = lea_maxn 
y2 = lea_minn
y3 = evs_maxn
y4 = evs_minn
z1 = np.polyfit(x1, y1, 1)
p1 = np.poly1d(z1)
z2 = np.polyfit(x1, y2, 1)
p2 = np.poly1d(z2)
z3 = np.polyfit(x2, y3, 1)
p3 = np.poly1d(z3)
#z4 = np.polyfit(x2, y4, 1)
#p4 = np.poly1d(z4)

plt.plot(x2, y3, 'g.')
plt.plot(x2, y4, 'm.')
plt.plot(x2, p3(x2),"g--")
#plt.plot(x2, p4(x2),"m--")
plt.plot(x1, y1, 'b.-')
plt.plot(x1, y2, 'b.-')
plt.plot(x1, p1(x1),"b--")
plt.plot(x1, p2(x1),"b--")
plt.gca().invert_yaxis()

plt.title('SMC Cepheids in the CEVS')
plt.xlabel('log(Period)')
plt.ylabel('Brightness')

#plt.savefig('Fig1_New.pdf', bboxes='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7666666666667">

# %% [markdown]
# ## Weird Minima Outliers

# %%
evs2 = np.genfromtxt('EVS_CAT_SMC.txt', usecols=(0,6,7,9))
evs2_number, evs2_max, evs2_min, evs2_per = evs2[:,0], evs2[:,1], evs2[:,2], evs2[:,3]
evs2_pern = np.sort(evs2_per)
ind = np.argsort(evs2_per)
evs2_maxn = evs2_max[ind]
evs2_minn = evs2_min[ind]
what = np.sort(evs2_minn)
what_ind = np.argsort(evs2_min)
outliers = evs2_number[what_ind]
print(outliers[0:6]) #The first six entries in this array are the number of the minima outliers.
# Out:
# [901843. 901478. 901124. 901133. 901068. 900420.]

# %% [markdown]
# ### To do next: Only plot brightnesses measured in the P band, to match Leavitt.
